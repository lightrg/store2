# %%
# %pylab inline

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd
## Add import here to save a static insight

# %%
dataset_heart_disease_prepared = dataiku.Dataset("heart_disease_prepared")
df = dataset_heart_disease_prepared.get_dataframe()

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(bins=20,ax = ax)
plt.show()

# %%
## save the above figure as a static insight

# %%
df.groupby(['sex', 'risk_level']).mean()
